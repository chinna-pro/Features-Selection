# %% [markdown]
# ### Information gain and Mutual information in Classification

# %%
import pandas as pd

# %%
df=pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    int64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
### Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['Wine'],axis=1),
                                                       df['Wine'],
                                                       test_size=0.3,
                                                       random_state=0)

# %%
X_train.head()
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 22     13.71        1.86  2.36  16.6  101     2.61        2.88
# 108    12.22        1.29  1.94  19.0   92     2.36        2.04
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 145    13.16        3.57  2.15  21.0  102     1.50        0.55
# 71     13.86        1.51  2.67  25.0   86     2.95        2.86
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 22                   0.27     1.69       3.80  1.11  4.00     1035
# 108                  0.39     2.08       2.70  0.86  3.02      312
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 145                  0.43     1.30       4.00  0.60  1.68      830
# 71                   0.21     1.87       3.38  1.36  3.16      410

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train,y_train)
mutual_info
# Out:
# array([0.41960627, 0.30981392, 0.16669371, 0.22789969, 0.20725858,
#        0.49649857, 0.71994843, 0.11812876, 0.26943134, 0.62090659,
#        0.57215826, 0.54712454, 0.5393031 ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Flavanoids              0.719948
# Color.int               0.620907
# Hue                     0.572158
# OD                      0.547125
# Proline                 0.539303
# Phenols                 0.496499
# Alcohol                 0.419606
# Malic.acid              0.309814
# Proanth                 0.269431
# Acl                     0.227900
# Mg                      0.207259
# Ash                     0.166694
# Nonflavanoid.phenols    0.118129
# dtype: float64

# %%
X_train.columns
# Out:
# Index(['Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols', 'Flavanoids',
#        'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue', 'OD', 'Proline'],
#       dtype='object')

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest

# %%
# Now we will select the top five important features
fiv_cols = SelectKBest(mutual_info_classif,k=5)
fiv_cols.fit(X_train,y_train)
X_train.columns[fiv_cols.get_support()]
# Out:
# Index(['Flavanoids', 'Color.int', 'Hue', 'OD', 'Proline'], dtype='object')

# %% [markdown]
# ### Information gain and mutual information in Regression

# %%
import pandas as pd
house_df=pd.read_csv('house.csv')

# %%
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_lst=['int16','int32','int64','float16','float32','float64']
numerical_cols = list(house_df.select_dtypes(include=numeric_lst).columns)

# %%
numerical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
housing_df=house_df[numerical_cols]

# %%
housing_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
housing_df=housing_df.drop("Id",axis=1)

# %%
housing_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
### Train test split to avoid over fitting
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(housing_df.drop(labels=['SalePrice'],axis=1),
                                                       housing_df['SalePrice'],
                                                       test_size=0.3,
                                                       random_state=0)

# %%
X_train.isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 64            60          NaN     9375            7            5       1997
# 682          120          NaN     2887            6            5       1996
# 960           20         50.0     7207            5            7       1958
# 1384          50         60.0     9060            6            5       1939
# 1100          30         60.0     8400            2            5       1920
# ...          ...          ...      ...          ...          ...        ...
# 763           60         82.0     9430            8            5       1999
# 835           20         60.0     9600            4            7       1950
# 1216          90         68.0     8930            6            5       1978
# 559          120          NaN     3196            7            5       2003
# 684           60         58.0    16770            7            5       1998
#
# ...

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train.fillna(0), y_train)
mutual_info
# Out:
# array([0.24396547, 0.21576287, 0.16615525, 0.52457012, 0.10813731,
#        0.34245586, 0.25768235, 0.10125051, 0.15990489, 0.00287311,
#        0.11164331, 0.3845188 , 0.30826766, 0.22810989, 0.0078367 ,
#        0.48186892, 0.01508997, 0.01482464, 0.27647365, 0.0827677 ,
#        0.04250892, 0.01682694, 0.18875337, 0.17789661, 0.26145528,
#        0.37070207, 0.37080898, 0.0770591 , 0.16969856, 0.02390024,
#        0.00470632, 0.03426174, 0.        , 0.        , 0.        ,
#        0.00477332])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.524570
# GrLivArea        0.481869
# TotalBsmtSF      0.384519
# GarageArea       0.370809
# GarageCars       0.370702
# YearBuilt        0.342456
# 1stFlrSF         0.308268
# FullBath         0.276474
# GarageYrBlt      0.261455
# YearRemodAdd     0.257682
# MSSubClass       0.243965
# 2ndFlrSF         0.228110
# LotFrontage      0.215763
# TotRmsAbvGrd     0.188753
# Fireplaces       0.177897
# OpenPorchSF      0.169699
# LotArea          0.166155
# BsmtFinSF1       0.159905
# BsmtUnfSF        0.111643
# OverallCond      0.108137
# MasVnrArea       0.101251
# HalfBath         0.082768
# WoodDeckSF       0.077059
# BedroomAbvGr     0.042509
# ScreenPorch      0.034262
# EnclosedPorch    0.023900
# KitchenAbvGr     0.016827
# BsmtFullBath     0.015090
# BsmtHalfBath     0.014825
# LowQualFinSF     0.007837
# YrSold           0.004773
# 3SsnPorch        0.004706
# BsmtFinSF2       0.002873
# PoolArea         0.000000
# MiscVal          0.000000
# ...

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectPercentile

# %%
### selecting the top 20 percentile
top_twenty=SelectPercentile(mutual_info_regression, percentile=20)
top_twenty.fit(X_train.fillna(0), y_train)
X_train.columns[top_twenty.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
top_twenty.get_support()
# Out:
# array([False, False, False,  True, False,  True, False, False, False,
#        False, False,  True,  True, False, False,  True, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False])
